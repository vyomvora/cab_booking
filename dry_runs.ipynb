# %%
import googlemaps

API_KEY = "AIzaSyALaK60mN_SCmnYnn2nuEp9KMyd4UvATDk"
gmaps = googlemaps.Client(key=API_KEY)

def get_distance(pickup, dropoff):
    result = gmaps.distance_matrix(pickup, dropoff, mode="driving")
    if result["status"] == "OK":
        distance = result["rows"][0]["elements"][0]["distance"]["text"]
        duration = result["rows"][0]["elements"][0]["duration"]["text"]
        return distance, duration
    return None, None

pickup_location = "New York, NY"
dropoff_location = "Los Angeles, CA"

distance, duration = get_distance(pickup_location, dropoff_location)
if distance:
    print(f"Distance: {distance}, Duration: {duration}")
else:
    print("Could not retrieve distance data")
# Out:
# ---------------------------------------------------------------------------
# ApiError                                  Traceback (most recent call last)
# Cell In[2], line 17
#      14 pickup_location = "New York, NY"
#      15 dropoff_location = "Los Angeles, CA"
# ---> 17 distance, duration = get_distance(pickup_location, dropoff_location)
#      18 if distance:
#      19     print(f"Distance: {distance}, Duration: {duration}")
#
# Cell In[2], line 7, in get_distance(pickup, dropoff)
#       6 def get_distance(pickup, dropoff):
# ----> 7     result = gmaps.distance_matrix(pickup, dropoff, mode="driving")
#       8     if result["status"] == "OK":
#       9         distance = result["rows"][0]["elements"][0]["distance"]["text"]
#
# File d:\devsecops\devsecops\Lib\site-packages\googlemaps\client.py:445, in make_api_method.<locals>.wrapper(*args, **kwargs)
#     442 @functools.wraps(func)
#     443 def wrapper(*args, **kwargs):
# ...

# %%
import googlemaps, requests,json

API_KEY = "AIzaSyALaK60mN_SCmnYnn2nuEp9KMyd4UvATDk"
url ='https://maps.googleapis.com/maps/api/distancematrix/json?'
pickup_location = "New York, NY"
dropoff_location = "Los Angeles, CA"
# Get method of requests module
# return response object
r = requests.get(url + 'origins = ' + pickup_location +
                   '&destinations = ' + dropoff_location +
                   '&key = ' + API_KEY)
                    
x = r.json()

# %%
def _calculate_distance(self, origin: str, destination: str) -> float:
        """Calculate distance in miles between two addresses"""
        try:
            result = self.gmaps.distance_matrix(origin, destination, units="imperial")
            if result['rows'][0]['elements'][0]['status'] != "OK":
                raise HTTPException(status_code=400, detail="Unable to calculate distance")
            return result['rows'][0]['elements'][0]['distance']['value'] / 1609.34
        except Exception as e:
            raise f"Error calculating distance: {str(e)}"
# Out:
# {'destination_addresses': [],
#  'error_message': 'You must use an API key to authenticate each request to Google Maps Platform APIs. For additional information, please refer to http://g.co/dev/maps-no-account',
#  'origin_addresses': [],
#  'rows': [],
#  'status': 'REQUEST_DENIED'}

# %%
import os
import smtplib
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart


# Email configuration 
EMAIL_HOST = os.environ.get('EMAIL_HOST', 'smtp.gmail.com')
EMAIL_PORT = int(os.environ.get('EMAIL_PORT', 587))
EMAIL_USERNAME = os.environ.get('EMAIL_USERNAME', 'cabbook66@gmail.com')
EMAIL_PASSWORD = os.environ.get('EMAIL_PASSWORD', 'ybxq sheq rjjh lwgv')
EMAIL_FROM = os.environ.get('EMAIL_FROM', 'Cab Booking Service <noreply@cabbooking.com>')



def send_booking_confirmation():
    try:
        # Create email message
        msg = MIMEMultipart('alternative')
        msg['Subject'] = 'Your Cab Booking Confirmation'
        msg['From'] = EMAIL_FROM
        msg['To'] = "dhruvjani044@gmail.com"  # Assuming user model has email field
        
        # HTML Email Template
        html = f"""
        <!DOCTYPE html>
        <html>
        <head>
            <style>
                body {{
                    font-family: Arial, sans-serif;
                    line-height: 1.6;
                    color: #333;
                }}
                .container {{
                    max-width: 600px;
                    margin: 0 auto;
                    padding: 20px;
                    border: 1px solid #ddd;
                    border-radius: 5px;
                }}
                .header {{
                    background-color: #4a90e2;
                    color: white;
                    padding: 15px;
                    text-align: center;
                    border-radius: 5px 5px 0 0;
                }}
                .content {{
                    padding: 20px;
                }}
                .booking-details {{
                    background-color: #f9f9f9;
                    padding: 15px;
                    border-radius: 5px;
                    margin-bottom: 20px;
                }}
                .detail-row {{
                    margin-bottom: 10px;
                }}
                .label {{
                    font-weight: bold;
                }}
                .footer {{
                    text-align: center;
                    padding: 15px;
                    font-size: 12px;
                    color: #777;
                }}
            </style>
        </head>
        <body>
            <div class="container">
                <div class="header">
                    <h1>Booking Confirmation</h1>
                </div>
                <div class="content">
                    <p>Dear {'ArithmeticErrorshivang' if hasattr('shivang', 'name') else 'Customer'},</p>
                    
                    <p>Thank you for booking with our cab service. Your booking has been confirmed!</p>
                    
                    <div class="booking-details">
                        <div class="detail-row">
                            <span class="label">Booking ID:</span> 123
                        </div>
                        <div class="detail-row">
                            <span class="label">Date & Time:</span> 123
                        </div>
                        <div class="detail-row">
                            <span class="label">Car Type:</span> swoft
                        </div>
                        <div class="detail-row">
                            <span class="label">Pickup Location:</span> lucan
                        </div>
                        <div class="detail-row">
                            <span class="label">Drop-off Location:</span> dublin
                        </div>
                        <div class="detail-row">
                            <span class="label">Estimated Fare:</span> €2
                        </div>
                    </div>
                    
                    <p>To view your booking details or make changes, please log in to your account.</p>
                    
                    <p>If you have any questions about your booking, please contact our customer support at support@cabbooking.com.</p>
                    
                    <p>Thank you for choosing our service!</p>
                </div>
                <div class="footer">
                    <p>This is an automated message, please do not reply to this email.</p>
                    <p>&copy; 2025 Cab Booking Service. All rights reserved.</p>
                </div>
            </div>
        </body>
        </html>
        """
        
        # Attach HTML content
        part = MIMEText(html, 'html')
        msg.attach(part)
        
        # Connect to mail server and send email
        server = smtplib.SMTP(EMAIL_HOST, EMAIL_PORT)
        server.starttls()
        server.login(EMAIL_USERNAME, EMAIL_PASSWORD)
        server.sendmail(EMAIL_FROM, "dhruvjani044@gmail.com", msg.as_string())
        server.quit()
        
        return True
    except Exception as e:
        print(f"Failed to send email: {str(e)}")
        return False

# %%
send_booking_confirmation()
# Out:
# True
